# %%
# Tratamiento de datos
import numpy as np
import pandas as pd
import pickle
pd.set_option('display.max_columns', None)
import pickle
import math
from scipy import stats
from datetime import datetime

# Gráficos
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,8)

# warnings
import warnings
warnings.filterwarnings('ignore')
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

#scr
import sys
sys.path.append("../")
import src.support as sp

# %% [markdown]
# # input

# %%
df = pd.read_csv('../data/train.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1   1   1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# 2   2   0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54  7.983
# 3   3   1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12  8.371
# 4   4   0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82  6.588

# %% [markdown]
# # EDA
# 1. ver que tengo en el df y los tipos

# %%
sp.analisis_basico(df)
# Out:
# _________________________________
#
# 1_Estructura de los datos: (40455, 11)
#    id  carat      cut color clarity  depth  table     x     y     z  price
# 0   0   0.30  Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1   1   1.01    Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40455 non-null  int64
#  1   carat    40455 non-null  float64
#  2   cut      40455 non-null  object
#  3   color    40455 non-null  object
#  4   clarity  40455 non-null  object
#  5   depth    40455 non-null  float64
#  6   table    40455 non-null  float64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
#  10  price    40455 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# ...

# %% [markdown]
# **variables:**
# - `id`: only for test & sample submission files, id for prediction sample identification
# - `price`: price in USD
# - `carat`: weight of the diamond
# - `cut`: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# - `color`: diamond colour
# - `clarity`: a measurement of how clear the diamond is
# - `x`: length in mm
# - `y`: width in mm
# - `z`: depth in mm
# - `depth`: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# - `table`: width of top of diamond relative to widest point (43--95)
#
# las variables `x`, `y`, `z` están relacionadas con `depth` y `table`, por lo que las podemos eliminar.

# %% [markdown]
# las variables que quedan en el dataset serían las sigueintes:
# - variable respuesta:
#     - `price`
# - variables numéricas:
#     - `carat`
#     - `depth`
#     - `table`
# - variables categóricas:
#     - `clarity`
#     - `cut`
#     - `color`

# %% [markdown]
# ## variable respuesta

# %% [markdown]
# la variable respuesta es de tipo numérico y continua, por lo que el modelo de predicción será del tipo regresión lineal.

# %%
# cuantas casas tienen de media el valor que indica el eje x
sns.histplot(data = df, x = 'price', kde = True)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %% [markdown]
# mirando la variable respuesta, no es normal. intentaremos posteriormente ver si se puede hacer una regresión lineal, sino emplearemos otros tipos de modelos.

# %% [markdown]
# ## variables predictoras
# ### variables numéricas

# %%
sp.regplot_numericas(df, ['id', 'price'], 'price')

# %% [markdown]
# la única que está verdaderamente relacionada con el precio es `carat`. Lo revisaremos con el heatmap para ver la correlación

# %% [markdown]
# ## correlación de las variables

# %%
sns.heatmap(df.corr(), 
           cmap = "YlGnBu",
           annot = True);

# %% [markdown]
# ## variables categóricas

# %%
sp.chart_categoricas_value(df, 'price')
# Out:
# este chart da la relación de las variables categóricas con la variable respuesta: price

# %%
sp.chart_categoricas_count(df)
# Out:
# este chart da la distribución de las variables categóricas

# %% [markdown]
# las variables categóricas vemos que parecen tener orden debido al count -> el encoding será de tipo ordinal
# <br>sin embargo, mirando la relación de las variables con el precio, parecen muy similares, sin embargo las categorías son muy importantes para determinar el precio de los diamantes, por lo que se probarán diferentes encoding ordenados.

# %% [markdown]
# # resumen

# %% [markdown]
# al final, las variables que más importan a la hora de valorar los diamantes según la correlación (o sea, las variables numéricas), son: `carat`, `x`, `y`, `z`. el resto de las columnas numéricas no parecen tener un impacto significativo en el precio.

# %% [markdown]
# buscando información sobre que cualidades son las determinantes a la hora de valorar un diamante, equivalen a las siguientes columnas:
# - `carat`
# - `clarity`
# -  `color`
# - `cut`
#
# lo que quiere decir que todas las columnas categóricas son determinantes para el precio. por tanto, debemos aplicarles un encoding concreto, ya que eso puede determinar el precio final del diamante, si tiene mejores propiedades de las variables dadas.
